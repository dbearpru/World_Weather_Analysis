# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | los llanos de aridane
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | hofn
# Processing Record 6 of Set 1 | roma
# Processing Record 7 of Set 1 | teluknaga
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | bataipora
# Processing Record 15 of Set 1 | kysyl-syr
# Processing Record 16 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 1 | pochutla
# Processing Record 18 of Set 1 | harper
# Processing Record 19 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | akureyri
# Processing Record 23 of Set 1 | henties bay
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | brae
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | shelburne
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | naze
# Processing Record 31 of Set 1 | nadapuram
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | itarema
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | namibe
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | guhagar
# Processing Record 44 of Set 1 | bandarbeyla
# Processing Record 45 of Set 1 | sturgeon falls
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | lixourion
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | teya
# Processing Record 50 of Set 1 | rorvik
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | leh
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | westport
# Processing Record 7 of Set 2 | cravo norte
# Processing Record 8 of Set 2 | serravalle
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | dickinson
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | yashalta
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | vostok
# Processing Record 16 of Set 2 | cestas
# Processing Record 17 of Set 2 | chenghai
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | yulara
# Processing Record 23 of Set 2 | komsomolskiy
# Processing Record 24 of Set 2 | puerto quijarro
# Processing Record 25 of Set 2 | roald
# Processing Record 26 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | spitak
# Processing Record 32 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 33 of Set 2 | necochea
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | kitgum
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | sedam
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | grand-bourg
# Processing Record 41 of Set 2 | zaysan
# Processing Record 42 of Set 2 | chaadayevka
# Processing Record 43 of Set 2 | boende
# Processing Record 44 of Set 2 | karpuninskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | abu dhabi
# Processing Record 46 of Set 2 | barrhead
# Processing Record 47 of Set 2 | belinskiy
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | klaksvik
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | megion
# Processing Record 3 of Set 3 | oldham
# Processing Record 4 of Set 3 | husavik
# Processing Record 5 of Set 3 | margate
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 3 | maungaturoto
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | sechura
# Processing Record 13 of Set 3 | balykshi
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | formosa
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | zharkent
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | adrar
# Processing Record 20 of Set 3 | mayo
# Processing Record 21 of Set 3 | garca
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | hirara
# Processing Record 25 of Set 3 | san andres
# Processing Record 26 of Set 3 | saint-augustin
# Processing Record 27 of Set 3 | santa fe
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | kununurra
# Processing Record 32 of Set 3 | dingle
# Processing Record 33 of Set 3 | tezu
# Processing Record 34 of Set 3 | ukiah
# Processing Record 35 of Set 3 | saint-georges
# Processing Record 36 of Set 3 | punta arenas
# Processing Record 37 of Set 3 | sibolga
# Processing Record 38 of Set 3 | deputatskiy
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | chapais
# Processing Record 44 of Set 3 | fukue
# Processing Record 45 of Set 3 | hervey bay
# Processing Record 46 of Set 3 | bilma
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | xai-xai
# Processing Record 1 of Set 4 | altagracia de orituco
# Processing Record 2 of Set 4 | mecca
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | saint anthony
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | sangar
# Processing Record 7 of Set 4 | mildura
# Processing Record 8 of Set 4 | amapa
# Processing Record 9 of Set 4 | khash
# Processing Record 10 of Set 4 | tucuma
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | seoul
# Processing Record 13 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 4 | mount isa
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | labuhan
# Processing Record 17 of Set 4 | nome
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | sjenica
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | cascais
# Processing Record 22 of Set 4 | studina
# Processing Record 23 of Set 4 | derzhavinsk
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | enniscorthy
# Processing Record 26 of Set 4 | xuddur
# Processing Record 27 of Set 4 | haines junction
# Processing Record 28 of Set 4 | kalmunai
# Processing Record 29 of Set 4 | hami
# Processing Record 30 of Set 4 | porbandar
# Processing Record 31 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 4 | half moon bay
# Processing Record 33 of Set 4 | fairbanks
# Processing Record 34 of Set 4 | atasu
# Processing Record 35 of Set 4 | bucerias
# Processing Record 36 of Set 4 | el alto
# Processing Record 37 of Set 4 | nouadhibou
# Processing Record 38 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 4 | vaini
# Processing Record 40 of Set 4 | macenta
# Processing Record 41 of Set 4 | kozelsk
# Processing Record 42 of Set 4 | rawson
# Processing Record 43 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 4 | zhezkazgan
# Processing Record 45 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 4 | sept-iles
# Processing Record 47 of Set 4 | along
# Processing Record 48 of Set 4 | aksu
# Processing Record 49 of Set 4 | domoni
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | careiro da varzea
# Processing Record 3 of Set 5 | tomatlan
# Processing Record 4 of Set 5 | port hedland
# Processing Record 5 of Set 5 | buala
# Processing Record 6 of Set 5 | saint-pierre
# Processing Record 7 of Set 5 | port said
# Processing Record 8 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | natal
# Processing Record 11 of Set 5 | naron
# Processing Record 12 of Set 5 | coahuayana
# Processing Record 13 of Set 5 | springbok
# Processing Record 14 of Set 5 | diebougou
# Processing Record 15 of Set 5 | khasan
# Processing Record 16 of Set 5 | kloulklubed
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | ingham
# Processing Record 19 of Set 5 | honiara
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | zhigansk
# Processing Record 22 of Set 5 | taoudenni
# Processing Record 23 of Set 5 | cognac
# Processing Record 24 of Set 5 | itaqui
# Processing Record 25 of Set 5 | chara
# Processing Record 26 of Set 5 | mumford
# Processing Record 27 of Set 5 | grand-santi
# Processing Record 28 of Set 5 | genhe
# Processing Record 29 of Set 5 | abha
# Processing Record 30 of Set 5 | waddan
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | pevek
# Processing Record 33 of Set 5 | praya
# Processing Record 34 of Set 5 | bambous virieux
# Processing Record 35 of Set 5 | goderich
# Processing Record 36 of Set 5 | kourou
# Processing Record 37 of Set 5 | we
# City not found. Skipping...
# Processing Record 38 of Set 5 | nicolas bravo
# Processing Record 39 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 5 | yar-sale
# Processing Record 41 of Set 5 | te anau
# Processing Record 42 of Set 5 | rakaia
# Processing Record 43 of Set 5 | catole do rocha
# Processing Record 44 of Set 5 | rocha
# Processing Record 45 of Set 5 | sao joao da barra
# Processing Record 46 of Set 5 | aklavik
# Processing Record 47 of Set 5 | kirovskiy
# Processing Record 48 of Set 5 | cape town
# Processing Record 49 of Set 5 | mariestad
# Processing Record 50 of Set 5 | ambon
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | hasaki
# Processing Record 4 of Set 6 | andenes
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | edeia
# Processing Record 7 of Set 6 | paamiut
# Processing Record 8 of Set 6 | ruidoso
# Processing Record 9 of Set 6 | alamos
# Processing Record 10 of Set 6 | cayenne
# Processing Record 11 of Set 6 | vanimo
# Processing Record 12 of Set 6 | sorland
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | montmagny
# Processing Record 17 of Set 6 | olafsvik
# Processing Record 18 of Set 6 | wajima
# Processing Record 19 of Set 6 | puerto colombia
# Processing Record 20 of Set 6 | soanierana ivongo
# Processing Record 21 of Set 6 | nikolskoye
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | medicine hat
# Processing Record 24 of Set 6 | arinos
# Processing Record 25 of Set 6 | hit
# Processing Record 26 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 6 | lumphat
# Processing Record 28 of Set 6 | amga
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | rundu
# Processing Record 31 of Set 6 | dzaoudzi
# Processing Record 32 of Set 6 | pundaguitan
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | pisco
# Processing Record 35 of Set 6 | galle
# Processing Record 36 of Set 6 | ola
# Processing Record 37 of Set 6 | katobu
# Processing Record 38 of Set 6 | san patricio
# Processing Record 39 of Set 6 | carnarvon
# Processing Record 40 of Set 6 | lere
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | ayoquezco
# City not found. Skipping...
# Processing Record 43 of Set 6 | egvekinot
# Processing Record 44 of Set 6 | boke
# Processing Record 45 of Set 6 | bam
# Processing Record 46 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 6 | braganca
# Processing Record 48 of Set 6 | san quintin
# Processing Record 49 of Set 6 | cristalina
# Processing Record 50 of Set 6 | muravlenko
# Processing Record 1 of Set 7 | bara
# Processing Record 2 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 3 of Set 7 | lorengau
# Processing Record 4 of Set 7 | kayerkan
# Processing Record 5 of Set 7 | gachala
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | guaratinga
# Processing Record 8 of Set 7 | nsanje
# Processing Record 9 of Set 7 | poum
# Processing Record 10 of Set 7 | general pico
# Processing Record 11 of Set 7 | tual
# Processing Record 12 of Set 7 | the valley
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | nyurba
# Processing Record 15 of Set 7 | porto novo
# Processing Record 16 of Set 7 | oum hadjer
# Processing Record 17 of Set 7 | ubinskoye
# Processing Record 18 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 7 | kabompo
# Processing Record 20 of Set 7 | lagoa
# Processing Record 21 of Set 7 | ruwi
# Processing Record 22 of Set 7 | hisua
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | parkes
# Processing Record 25 of Set 7 | cabedelo
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | beipiao
# Processing Record 28 of Set 7 | ca mau
# Processing Record 29 of Set 7 | selu
# Processing Record 30 of Set 7 | sasykoli
# Processing Record 31 of Set 7 | takoradi
# Processing Record 32 of Set 7 | svetlyy
# Processing Record 33 of Set 7 | uvira
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | karanja
# Processing Record 36 of Set 7 | khatanga
# Processing Record 37 of Set 7 | moanda
# Processing Record 38 of Set 7 | kieta
# Processing Record 39 of Set 7 | constitucion
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | sobolevo
# Processing Record 42 of Set 7 | oranjemund
# Processing Record 43 of Set 7 | marechal floriano
# Processing Record 44 of Set 7 | berlevag
# Processing Record 45 of Set 7 | mackenzie
# Processing Record 46 of Set 7 | palana
# Processing Record 47 of Set 7 | okha
# Processing Record 48 of Set 7 | rudnogorsk
# Processing Record 49 of Set 7 | matagami
# Processing Record 50 of Set 7 | khuzhir
# Processing Record 1 of Set 8 | srednekolymsk
# Processing Record 2 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | atar
# Processing Record 4 of Set 8 | palmares do sul
# Processing Record 5 of Set 8 | jardim
# Processing Record 6 of Set 8 | denpasar
# Processing Record 7 of Set 8 | trabzon
# Processing Record 8 of Set 8 | tahoua
# Processing Record 9 of Set 8 | walvis bay
# Processing Record 10 of Set 8 | jacareacanga
# Processing Record 11 of Set 8 | alausi
# Processing Record 12 of Set 8 | treinta y tres
# Processing Record 13 of Set 8 | hamilton
# Processing Record 14 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 8 | alofi
# Processing Record 16 of Set 8 | bosaso
# Processing Record 17 of Set 8 | faanui
# Processing Record 18 of Set 8 | pashiya
# Processing Record 19 of Set 8 | nichinan
# Processing Record 20 of Set 8 | acapulco
# Processing Record 21 of Set 8 | biak
# Processing Record 22 of Set 8 | casalnuovo di napoli
# Processing Record 23 of Set 8 | kuandian
# Processing Record 24 of Set 8 | shenzhen
# Processing Record 25 of Set 8 | aswan
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | tadine
# Processing Record 28 of Set 8 | pangnirtung
# Processing Record 29 of Set 8 | meulaboh
# Processing Record 30 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 31 of Set 8 | sampit
# Processing Record 32 of Set 8 | mariinsk
# Processing Record 33 of Set 8 | santa cruz
# Processing Record 34 of Set 8 | asau
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | peniche
# Processing Record 37 of Set 8 | inirida
# Processing Record 38 of Set 8 | shache
# Processing Record 39 of Set 8 | ust-maya
# Processing Record 40 of Set 8 | esperance
# Processing Record 41 of Set 8 | batagay-alyta
# Processing Record 42 of Set 8 | shingu
# Processing Record 43 of Set 8 | bontang
# Processing Record 44 of Set 8 | sikandra rao
# Processing Record 45 of Set 8 | dudinka
# Processing Record 46 of Set 8 | bilokurakyne
# Processing Record 47 of Set 8 | luanda
# Processing Record 48 of Set 8 | tamale
# Processing Record 49 of Set 8 | tibati
# Processing Record 50 of Set 8 | elat
# Processing Record 1 of Set 9 | glace bay
# Processing Record 2 of Set 9 | balabac
# Processing Record 3 of Set 9 | mandera
# Processing Record 4 of Set 9 | igunga
# Processing Record 5 of Set 9 | harlingen
# Processing Record 6 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 9 | diamantino
# Processing Record 8 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 9 | celestun
# Processing Record 10 of Set 9 | gigmoto
# Processing Record 11 of Set 9 | saiha
# Processing Record 12 of Set 9 | yerbogachen
# Processing Record 13 of Set 9 | beloha
# Processing Record 14 of Set 9 | penzance
# Processing Record 15 of Set 9 | bilibino
# Processing Record 16 of Set 9 | taltal
# Processing Record 17 of Set 9 | lyubeshiv
# City not found. Skipping...
# Processing Record 18 of Set 9 | saldanha
# Processing Record 19 of Set 9 | guymon
# Processing Record 20 of Set 9 | sakhnovshchyna
# Processing Record 21 of Set 9 | caltagirone
# Processing Record 22 of Set 9 | sabzevar
# Processing Record 23 of Set 9 | madimba
# Processing Record 24 of Set 9 | almaya
# Processing Record 25 of Set 9 | terrace
# Processing Record 26 of Set 9 | dawlatabad
# Processing Record 27 of Set 9 | doembang nangbuat
# Processing Record 28 of Set 9 | magistralnyy
# Processing Record 29 of Set 9 | mayahi
# Processing Record 30 of Set 9 | qarqin
# Processing Record 31 of Set 9 | erzin
# Processing Record 32 of Set 9 | san pedro
# Processing Record 33 of Set 9 | nishihara
# Processing Record 34 of Set 9 | matamba
# Processing Record 35 of Set 9 | peterhead
# Processing Record 36 of Set 9 | codrington
# Processing Record 37 of Set 9 | trelew
# Processing Record 38 of Set 9 | port keats
# Processing Record 39 of Set 9 | itaituba
# Processing Record 40 of Set 9 | corrente
# Processing Record 41 of Set 9 | takaka
# Processing Record 42 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 9 | ekibastuz
# Processing Record 44 of Set 9 | katha
# City not found. Skipping...
# Processing Record 45 of Set 9 | agnibilekrou
# Processing Record 46 of Set 9 | les cayes
# Processing Record 47 of Set 9 | san cristobal
# Processing Record 48 of Set 9 | broceni
# Processing Record 49 of Set 9 | awjilah
# Processing Record 50 of Set 9 | worcester
# Processing Record 1 of Set 10 | vila franca do campo
# Processing Record 2 of Set 10 | kruisfontein
# Processing Record 3 of Set 10 | abnub
# Processing Record 4 of Set 10 | palmer
# Processing Record 5 of Set 10 | bairiki
# Processing Record 6 of Set 10 | zaragoza
# Processing Record 7 of Set 10 | marawi
# Processing Record 8 of Set 10 | huarmey
# Processing Record 9 of Set 10 | dmitrovsk-orlovskiy
# Processing Record 10 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 10 | narsaq
# Processing Record 12 of Set 10 | xining
# Processing Record 13 of Set 10 | inuvik
# Processing Record 14 of Set 10 | unye
# City not found. Skipping...
# Processing Record 15 of Set 10 | salcininkai
# Processing Record 16 of Set 10 | petropavlovka
# Processing Record 17 of Set 10 | agadir
# Processing Record 18 of Set 10 | buchanan
# Processing Record 19 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 20 of Set 10 | dolores
# Processing Record 21 of Set 10 | sitka
# Processing Record 22 of Set 10 | lasa
# Processing Record 23 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 10 | kayes
# Processing Record 25 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 10 | lugovoy
# Processing Record 27 of Set 10 | matamoros
# Processing Record 28 of Set 10 | klamath falls
# Processing Record 29 of Set 10 | severo-kurilsk
# Processing Record 30 of Set 10 | kalino
# Processing Record 31 of Set 10 | faridpur
# Processing Record 32 of Set 10 | evensk
# Processing Record 33 of Set 10 | karratha
# Processing Record 34 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 35 of Set 10 | kodiak
# Processing Record 36 of Set 10 | morondava
# Processing Record 37 of Set 10 | lujan
# Processing Record 38 of Set 10 | mogadishu
# Processing Record 39 of Set 10 | krasnoselkup
# Processing Record 40 of Set 10 | deniliquin
# Processing Record 41 of Set 10 | georgetown
# Processing Record 42 of Set 10 | stornoway
# Processing Record 43 of Set 10 | okhotsk
# Processing Record 44 of Set 10 | ulladulla
# Processing Record 45 of Set 10 | kailua
# Processing Record 46 of Set 10 | caiaponia
# Processing Record 47 of Set 10 | kutum
# Processing Record 48 of Set 10 | portland
# Processing Record 49 of Set 10 | rapid valley
# Processing Record 50 of Set 10 | ambilobe
# Processing Record 1 of Set 11 | san buenaventura
# Processing Record 2 of Set 11 | jiangyou
# Processing Record 3 of Set 11 | ondo
# Processing Record 4 of Set 11 | verkhnevilyuysk
# Processing Record 5 of Set 11 | lata
# Processing Record 6 of Set 11 | tiznit
# Processing Record 7 of Set 11 | darhan
# Processing Record 8 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 11 | haimen
# Processing Record 10 of Set 11 | mbini
# Processing Record 11 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 11 | shediac
# Processing Record 13 of Set 11 | turbat
# Processing Record 14 of Set 11 | bardiyah
# Processing Record 15 of Set 11 | tura
# Processing Record 16 of Set 11 | barreirinhas
# Processing Record 17 of Set 11 | cap-aux-meules
# Processing Record 18 of Set 11 | ornes
# Processing Record 19 of Set 11 | ye
# City not found. Skipping...
# Processing Record 20 of Set 11 | macia
# Processing Record 21 of Set 11 | esna
# Processing Record 22 of Set 11 | talcahuano
# Processing Record 23 of Set 11 | ardakan
# Processing Record 24 of Set 11 | hutchinson
# Processing Record 25 of Set 11 | lucapa
# Processing Record 26 of Set 11 | lufilufi
# Processing Record 27 of Set 11 | duz
# City not found. Skipping...
# Processing Record 28 of Set 11 | lodja
# Processing Record 29 of Set 11 | nioro
# Processing Record 30 of Set 11 | sierning
# Processing Record 31 of Set 11 | baoying
# Processing Record 32 of Set 11 | tigil
# Processing Record 33 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 11 | uravakonda
# Processing Record 35 of Set 11 | hovd
# Processing Record 36 of Set 11 | singaparna
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 11 | bathsheba
# Processing Record 40 of Set 11 | changji
# Processing Record 41 of Set 11 | impfondo
# Processing Record 42 of Set 11 | butka
# Processing Record 43 of Set 11 | la asuncion
# Processing Record 44 of Set 11 | capelinha
# Processing Record 45 of Set 11 | kamenka
# Processing Record 46 of Set 11 | pinega
# Processing Record 47 of Set 11 | jilin
# Processing Record 48 of Set 11 | opatija
# Processing Record 49 of Set 11 | endicott
# Processing Record 50 of Set 11 | bridgeton
# Processing Record 1 of Set 12 | isoka
# Processing Record 2 of Set 12 | severo-yeniseyskiy
# Processing Record 3 of Set 12 | scarborough
# Processing Record 4 of Set 12 | mehamn
# Processing Record 5 of Set 12 | lac-au-saumon
# Processing Record 6 of Set 12 | aachen
# Processing Record 7 of Set 12 | seymchan
# Processing Record 8 of Set 12 | banbury
# Processing Record 9 of Set 12 | muncar
# Processing Record 10 of Set 12 | nizhnyaya omka
# Processing Record 11 of Set 12 | riyadh
# Processing Record 12 of Set 12 | chermoz
# Processing Record 13 of Set 12 | sur
# Processing Record 14 of Set 12 | kokopo
# Processing Record 15 of Set 12 | coolum beach
# Processing Record 16 of Set 12 | hangu
# Processing Record 17 of Set 12 | tatarsk
# Processing Record 18 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 12 | andilamena
# Processing Record 20 of Set 12 | yenagoa
# Processing Record 21 of Set 12 | casablanca
# Processing Record 22 of Set 12 | matadi
# Processing Record 23 of Set 12 | vysokogornyy
# Processing Record 24 of Set 12 | omboue
# Processing Record 25 of Set 12 | outjo
# Processing Record 26 of Set 12 | chicama
# Processing Record 27 of Set 12 | tazmalt
# Processing Record 28 of Set 12 | fort-shevchenko
# Processing Record 29 of Set 12 | staryy nadym
# Processing Record 30 of Set 12 | sorgun
# Processing Record 31 of Set 12 | broken hill
# Processing Record 32 of Set 12 | wanning
# Processing Record 33 of Set 12 | farsund
# Processing Record 34 of Set 12 | abu samrah
# Processing Record 35 of Set 12 | lompoc
# Processing Record 36 of Set 12 | nova olinda do norte
# Processing Record 37 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 12 | barreirinha
# Processing Record 39 of Set 12 | bahar
# Processing Record 40 of Set 12 | ketchikan
# Processing Record 41 of Set 12 | mugur-aksy
# Processing Record 42 of Set 12 | kita
# Processing Record 43 of Set 12 | muroto
# Processing Record 44 of Set 12 | pacific grove
# Processing Record 45 of Set 12 | xichang
# Processing Record 46 of Set 12 | natitingou
# Processing Record 47 of Set 12 | ranau
# Processing Record 48 of Set 12 | emerald
# Processing Record 49 of Set 12 | tautira
# Processing Record 50 of Set 12 | balkanabat
# Processing Record 1 of Set 13 | tres arroyos
# Processing Record 2 of Set 13 | namatanai
# Processing Record 3 of Set 13 | bar harbor
# Processing Record 4 of Set 13 | avera
# Processing Record 5 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 6 of Set 13 | newport
# Processing Record 7 of Set 13 | nadym
# Processing Record 8 of Set 13 | dodge city
# Processing Record 9 of Set 13 | ancud
# Processing Record 10 of Set 13 | krasnyy yar
# Processing Record 11 of Set 13 | weligama
# Processing Record 12 of Set 13 | veraval
# Processing Record 13 of Set 13 | arlit
# Processing Record 14 of Set 13 | sola
# Processing Record 15 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 13 | rafraf
# Processing Record 17 of Set 13 | marsh harbour
# Processing Record 18 of Set 13 | san luis
# Processing Record 19 of Set 13 | eskilstuna
# Processing Record 20 of Set 13 | verkhoyansk
# Processing Record 21 of Set 13 | troitskoye
# Processing Record 22 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 13 | taphan hin
# Processing Record 24 of Set 13 | uyuni
# Processing Record 25 of Set 13 | homer
# Processing Record 26 of Set 13 | santo domingo
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | taraz
# Processing Record 29 of Set 13 | paka
# Processing Record 30 of Set 13 | camacha
# Processing Record 31 of Set 13 | hualmay
# Processing Record 32 of Set 13 | mbandaka
# Processing Record 33 of Set 13 | ranong
# Processing Record 34 of Set 13 | saint simons
# Processing Record 35 of Set 13 | khorixas
# Processing Record 36 of Set 13 | san policarpo
# Processing Record 37 of Set 13 | lavrentiya
# Processing Record 38 of Set 13 | volot
# Processing Record 39 of Set 13 | bereda
# Processing Record 40 of Set 13 | matai
# Processing Record 41 of Set 13 | rosarito
# Processing Record 42 of Set 13 | ponta delgada
# Processing Record 43 of Set 13 | umm kaddadah
# Processing Record 44 of Set 13 | beziers
# Processing Record 45 of Set 13 | kemijarvi
# Processing Record 46 of Set 13 | abomey-calavi
# Processing Record 47 of Set 13 | port hardy
# Processing Record 48 of Set 13 | novochernorechenskiy
# Processing Record 49 of Set 13 | palkonda
# Processing Record 50 of Set 13 | johi
# Processing Record 1 of Set 14 | smolensk
# Processing Record 2 of Set 14 | porto nacional
# Processing Record 3 of Set 14 | liverpool
# Processing Record 4 of Set 14 | moron
# Processing Record 5 of Set 14 | sembe
# Processing Record 6 of Set 14 | port-cartier
# Processing Record 7 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 14 | esso
# Processing Record 9 of Set 14 | la ronge
# Processing Record 10 of Set 14 | inhambane
# Processing Record 11 of Set 14 | chorozinho
# Processing Record 12 of Set 14 | gat
# Processing Record 13 of Set 14 | taxisco
# Processing Record 14 of Set 14 | sibu
# Processing Record 15 of Set 14 | carauari
# Processing Record 16 of Set 14 | emba
# Processing Record 17 of Set 14 | zhireken
# Processing Record 18 of Set 14 | high level
# Processing Record 19 of Set 14 | siuna
# Processing Record 20 of Set 14 | esmeraldas
# Processing Record 21 of Set 14 | bahia honda
# Processing Record 22 of Set 14 | auki
# Processing Record 23 of Set 14 | chernyshevskiy
# Processing Record 24 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 14 | zhangye
# Processing Record 26 of Set 14 | gavle
# Processing Record 27 of Set 14 | olpad
# Processing Record 28 of Set 14 | tres picos
# Processing Record 29 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 30 of Set 14 | asosa
# Processing Record 31 of Set 14 | oerlinghausen
# Processing Record 32 of Set 14 | kasongo-lunda
# Processing Record 33 of Set 14 | surt
# Processing Record 34 of Set 14 | camopi
# Processing Record 35 of Set 14 | anapskaya
# Processing Record 36 of Set 14 | bhuj
# Processing Record 37 of Set 14 | jutai
# Processing Record 38 of Set 14 | saryozek
# Processing Record 39 of Set 14 | alice springs
# Processing Record 40 of Set 14 | morehead
# Processing Record 41 of Set 14 | nanortalik
# Processing Record 42 of Set 14 | waipawa
# Processing Record 43 of Set 14 | vestmannaeyjar
# Processing Record 44 of Set 14 | tikrit
# Processing Record 45 of Set 14 | vestmanna
# Processing Record 46 of Set 14 | san matias
# Processing Record 47 of Set 14 | yelizovo
# Processing Record 48 of Set 14 | naryan-mar
# Processing Record 49 of Set 14 | gizo
# Processing Record 50 of Set 14 | sheopur
# Processing Record 1 of Set 15 | fort nelson
# Processing Record 2 of Set 15 | richards bay
# Processing Record 3 of Set 15 | vallenar
# Processing Record 4 of Set 15 | zofingen
# Processing Record 5 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 15 | uyskoye
# Processing Record 7 of Set 15 | buritizeiro
# Processing Record 8 of Set 15 | usinsk
# Processing Record 9 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 15 | promyshlennaya
# Processing Record 11 of Set 15 | sistranda
# Processing Record 12 of Set 15 | mayumba
# Processing Record 13 of Set 15 | comodoro rivadavia
# Processing Record 14 of Set 15 | iskilip
# Processing Record 15 of Set 15 | mandalgovi
# Processing Record 16 of Set 15 | bindura
# Processing Record 17 of Set 15 | nemuro
# Processing Record 18 of Set 15 | iskateley
# Processing Record 19 of Set 15 | bourail
# Processing Record 20 of Set 15 | borama
# City not found. Skipping...
# Processing Record 21 of Set 15 | tabora
# Processing Record 22 of Set 15 | jackson
# Processing Record 23 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 15 | sale
# Processing Record 25 of Set 15 | tessalit
# Processing Record 26 of Set 15 | vila
# Processing Record 27 of Set 15 | hurricane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Albany  42.6001  -73.9662     60.17        25           1
# 1  Los Llanos De Aridane  28.6585  -17.9182     67.12        78           0
# 2             Sao Filipe  14.8961  -24.4956     71.91        75           1
# 3              Upernavik  72.7868  -56.1549     -8.18        93          31
# 4                   Hofn  64.2539  -15.2082     45.61        95          87
# 5                   Roma  43.2128  -75.4557     59.72        31          40
# 6              Teluknaga  -6.0989  106.6381     82.18        83          40
# 7                Ushuaia -54.8000  -68.3000     44.22        93          40
# 8              Busselton -33.6500  115.3333     58.96        91           0
# 9                 Torbay  47.6666  -52.7314     43.88        66          65
#
#    Wind Speed Country Current Description
# 0        5.01      US           clear sky
# 1       16.11      ES           clear sky
# 2        9.44      CV           clear sky
# 3       12.73      GL    scattered clouds
# 4       10.36      IS     overcast clouds
# 5       14.97      US    scattered clouds
# 6        4.61      ID                haze
# 7        0.00      AR    scattered clouds
# 8        8.05      AU           clear sky
# 9        5.99      CA       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
