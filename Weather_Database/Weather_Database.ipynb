# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | helena
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | rawson
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | burica
# City not found. Skipping...
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | portland
# Processing Record 14 of Set 1 | taga
# Processing Record 15 of Set 1 | kapoeta
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | melfi
# Processing Record 20 of Set 1 | puerto del rosario
# Processing Record 21 of Set 1 | kamachumu
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | manaure
# Processing Record 24 of Set 1 | cururupu
# Processing Record 25 of Set 1 | haines junction
# Processing Record 26 of Set 1 | takoradi
# Processing Record 27 of Set 1 | touros
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 1 | kathu
# Processing Record 31 of Set 1 | chemal
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 1 | ambulu
# Processing Record 39 of Set 1 | luvianos
# Processing Record 40 of Set 1 | jasper
# Processing Record 41 of Set 1 | lincoln
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | faanui
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | cangucu
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | hambantota
# Processing Record 4 of Set 2 | grand gaube
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | beloha
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | verkhnevilyuysk
# Processing Record 10 of Set 2 | khasan
# Processing Record 11 of Set 2 | hofn
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | luorong
# Processing Record 14 of Set 2 | son la
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | sierra madre
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | sarkand
# Processing Record 21 of Set 2 | bulgan
# Processing Record 22 of Set 2 | buala
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | korla
# Processing Record 25 of Set 2 | alyangula
# Processing Record 26 of Set 2 | margate
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | sorland
# Processing Record 30 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 2 | ahipara
# Processing Record 32 of Set 2 | ericeira
# Processing Record 33 of Set 2 | inhambane
# Processing Record 34 of Set 2 | merauke
# Processing Record 35 of Set 2 | saldanha
# Processing Record 36 of Set 2 | minab
# Processing Record 37 of Set 2 | port-cartier
# Processing Record 38 of Set 2 | asau
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | santa vitoria do palmar
# Processing Record 41 of Set 2 | talara
# Processing Record 42 of Set 2 | ushuaia
# Processing Record 43 of Set 2 | puro
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | orange
# Processing Record 48 of Set 2 | poceirao
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | vestmanna
# Processing Record 1 of Set 3 | sinnamary
# Processing Record 2 of Set 3 | gamba
# Processing Record 3 of Set 3 | keokuk
# Processing Record 4 of Set 3 | lavrentiya
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | kununurra
# Processing Record 7 of Set 3 | jalu
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | college
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | coihaique
# City not found. Skipping...
# Processing Record 13 of Set 3 | gusinoye ozero
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | montepulciano
# Processing Record 17 of Set 3 | tura
# Processing Record 18 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 3 | zhicheng
# Processing Record 20 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 3 | pangnirtung
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | sitka
# Processing Record 25 of Set 3 | sao filipe
# Processing Record 26 of Set 3 | campbell river
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | tezu
# Processing Record 29 of Set 3 | general roca
# Processing Record 30 of Set 3 | buctzotz
# Processing Record 31 of Set 3 | ketchikan
# Processing Record 32 of Set 3 | santa cruz de tenerife
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | roebourne
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | rolante
# Processing Record 39 of Set 3 | xuddur
# Processing Record 40 of Set 3 | san quintin
# Processing Record 41 of Set 3 | homer
# Processing Record 42 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | romblon
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | dvinskoy
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | margherita
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | vila velha
# Processing Record 7 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 4 | biltine
# Processing Record 9 of Set 4 | chernivtsi
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | capao da canoa
# Processing Record 12 of Set 4 | kaoma
# Processing Record 13 of Set 4 | kushmurun
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | buluang
# Processing Record 16 of Set 4 | ixtapa
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | mazsalaca
# Processing Record 19 of Set 4 | topolobampo
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | bolobo
# Processing Record 22 of Set 4 | viedma
# Processing Record 23 of Set 4 | taoudenni
# Processing Record 24 of Set 4 | saint-joseph
# Processing Record 25 of Set 4 | coquimbo
# Processing Record 26 of Set 4 | tabriz
# Processing Record 27 of Set 4 | dumai
# Processing Record 28 of Set 4 | cockburn town
# Processing Record 29 of Set 4 | shimoda
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | buraydah
# Processing Record 33 of Set 4 | pevek
# Processing Record 34 of Set 4 | rio gallegos
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | igarka
# Processing Record 37 of Set 4 | kismayo
# Processing Record 38 of Set 4 | brae
# Processing Record 39 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 4 | pacific grove
# Processing Record 41 of Set 4 | koulikoro
# Processing Record 42 of Set 4 | trinidad
# Processing Record 43 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 4 | mazamari
# Processing Record 45 of Set 4 | namangan
# Processing Record 46 of Set 4 | kasangulu
# Processing Record 47 of Set 4 | ust-ilimsk
# Processing Record 48 of Set 4 | romitan
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | port hedland
# Processing Record 1 of Set 5 | shelburne
# Processing Record 2 of Set 5 | idlib
# Processing Record 3 of Set 5 | piacabucu
# Processing Record 4 of Set 5 | kribi
# Processing Record 5 of Set 5 | tonkino
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | rybinsk
# Processing Record 9 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | nacozari
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | rogun
# City not found. Skipping...
# Processing Record 13 of Set 5 | vila
# Processing Record 14 of Set 5 | mochumi
# Processing Record 15 of Set 5 | naryan-mar
# Processing Record 16 of Set 5 | suntar
# Processing Record 17 of Set 5 | san ramon
# Processing Record 18 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 5 | konevo
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | darnah
# Processing Record 22 of Set 5 | ribeira grande
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | trairi
# Processing Record 25 of Set 5 | new norfolk
# Processing Record 26 of Set 5 | myrtle grove
# Processing Record 27 of Set 5 | huancavelica
# Processing Record 28 of Set 5 | nikolskoye
# Processing Record 29 of Set 5 | denizli
# Processing Record 30 of Set 5 | georgetown
# Processing Record 31 of Set 5 | atar
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | rocha
# Processing Record 34 of Set 5 | marsh harbour
# Processing Record 35 of Set 5 | necochea
# Processing Record 36 of Set 5 | tumpat
# Processing Record 37 of Set 5 | kloulklubed
# Processing Record 38 of Set 5 | luganville
# Processing Record 39 of Set 5 | verkhoyansk
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | nouadhibou
# Processing Record 45 of Set 5 | cassilandia
# Processing Record 46 of Set 5 | lobito
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | fulton
# Processing Record 49 of Set 5 | arivonimamo
# Processing Record 50 of Set 5 | talaya
# Processing Record 1 of Set 6 | manuk mangkaw
# Processing Record 2 of Set 6 | qaanaaq
# Processing Record 3 of Set 6 | villa carlos paz
# Processing Record 4 of Set 6 | zonguldak
# Processing Record 5 of Set 6 | kuching
# Processing Record 6 of Set 6 | gumushane
# City not found. Skipping...
# Processing Record 7 of Set 6 | dubai
# Processing Record 8 of Set 6 | nassjo
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | samarai
# Processing Record 11 of Set 6 | acajutla
# Processing Record 12 of Set 6 | okha
# Processing Record 13 of Set 6 | palmer
# Processing Record 14 of Set 6 | montepuez
# Processing Record 15 of Set 6 | ulladulla
# Processing Record 16 of Set 6 | kashi
# Processing Record 17 of Set 6 | lazarev
# Processing Record 18 of Set 6 | marawi
# Processing Record 19 of Set 6 | ciudad bolivar
# Processing Record 20 of Set 6 | labuhan
# Processing Record 21 of Set 6 | casablanca
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | hasaki
# Processing Record 24 of Set 6 | hithadhoo
# Processing Record 25 of Set 6 | cabadiangan
# Processing Record 26 of Set 6 | emerald
# Processing Record 27 of Set 6 | ganta
# Processing Record 28 of Set 6 | taltal
# Processing Record 29 of Set 6 | erzin
# Processing Record 30 of Set 6 | amuntai
# Processing Record 31 of Set 6 | antalaha
# Processing Record 32 of Set 6 | sakakah
# Processing Record 33 of Set 6 | peleduy
# Processing Record 34 of Set 6 | lebu
# Processing Record 35 of Set 6 | waingapu
# Processing Record 36 of Set 6 | lenine
# Processing Record 37 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 6 | alta floresta
# Processing Record 39 of Set 6 | elk city
# Processing Record 40 of Set 6 | carnarvon
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | srednekolymsk
# Processing Record 43 of Set 6 | vila franca do campo
# Processing Record 44 of Set 6 | thinadhoo
# Processing Record 45 of Set 6 | dikson
# Processing Record 46 of Set 6 | berlevag
# Processing Record 47 of Set 6 | abha
# Processing Record 48 of Set 6 | novovasylivka
# Processing Record 49 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 6 | port blair
# Processing Record 1 of Set 7 | bengkulu
# Processing Record 2 of Set 7 | salalah
# Processing Record 3 of Set 7 | husavik
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | russell
# Processing Record 6 of Set 7 | porangatu
# Processing Record 7 of Set 7 | oussouye
# Processing Record 8 of Set 7 | karasburg
# Processing Record 9 of Set 7 | greenwood
# Processing Record 10 of Set 7 | lahaina
# Processing Record 11 of Set 7 | shipitsyno
# Processing Record 12 of Set 7 | marion
# Processing Record 13 of Set 7 | pecos
# Processing Record 14 of Set 7 | svetlaya
# Processing Record 15 of Set 7 | poum
# Processing Record 16 of Set 7 | huarmey
# Processing Record 17 of Set 7 | balkhash
# Processing Record 18 of Set 7 | wakkanai
# Processing Record 19 of Set 7 | masaya
# Processing Record 20 of Set 7 | metro
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 7 | montecristi
# Processing Record 25 of Set 7 | souillac
# Processing Record 26 of Set 7 | beringovskiy
# Processing Record 27 of Set 7 | kigali
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | kholm
# Processing Record 30 of Set 7 | hay river
# Processing Record 31 of Set 7 | marzuq
# Processing Record 32 of Set 7 | khandyga
# Processing Record 33 of Set 7 | albolote
# Processing Record 34 of Set 7 | mujiayingzi
# Processing Record 35 of Set 7 | stokmarknes
# Processing Record 36 of Set 7 | port hueneme
# Processing Record 37 of Set 7 | zatec
# Processing Record 38 of Set 7 | kimbe
# Processing Record 39 of Set 7 | senovo
# Processing Record 40 of Set 7 | colchester
# Processing Record 41 of Set 7 | gladstone
# Processing Record 42 of Set 7 | yerbogachen
# Processing Record 43 of Set 7 | rio grande
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | shaunavon
# Processing Record 46 of Set 7 | mayo
# Processing Record 47 of Set 7 | port hardy
# Processing Record 48 of Set 7 | algiers
# Processing Record 49 of Set 7 | shenjiamen
# Processing Record 50 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 8 | fengrun
# Processing Record 2 of Set 8 | prince rupert
# Processing Record 3 of Set 8 | konstantinovka
# Processing Record 4 of Set 8 | dongying
# Processing Record 5 of Set 8 | tombouctou
# Processing Record 6 of Set 8 | tevaitoa
# Processing Record 7 of Set 8 | vanderhoof
# Processing Record 8 of Set 8 | visnes
# Processing Record 9 of Set 8 | luanda
# Processing Record 10 of Set 8 | nabire
# Processing Record 11 of Set 8 | havelock
# Processing Record 12 of Set 8 | hanko
# Processing Record 13 of Set 8 | vangaindrano
# Processing Record 14 of Set 8 | kulu
# Processing Record 15 of Set 8 | hermiston
# Processing Record 16 of Set 8 | contamana
# Processing Record 17 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 18 of Set 8 | puerto narino
# Processing Record 19 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 8 | makung
# City not found. Skipping...
# Processing Record 21 of Set 8 | najran
# Processing Record 22 of Set 8 | lagos
# Processing Record 23 of Set 8 | lieksa
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | angoram
# Processing Record 26 of Set 8 | srandakan
# Processing Record 27 of Set 8 | lianran
# Processing Record 28 of Set 8 | luderitz
# Processing Record 29 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 8 | liverpool
# Processing Record 31 of Set 8 | iralaya
# Processing Record 32 of Set 8 | aswan
# Processing Record 33 of Set 8 | valdivia
# Processing Record 34 of Set 8 | visavadar
# Processing Record 35 of Set 8 | camopi
# Processing Record 36 of Set 8 | montauban
# Processing Record 37 of Set 8 | nishihara
# Processing Record 38 of Set 8 | andenes
# Processing Record 39 of Set 8 | awbari
# Processing Record 40 of Set 8 | sao paulo de olivenca
# Processing Record 41 of Set 8 | baykit
# Processing Record 42 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 8 | paracatu
# Processing Record 44 of Set 8 | narsaq
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | kahului
# Processing Record 48 of Set 8 | kiunga
# Processing Record 49 of Set 8 | klaksvik
# Processing Record 50 of Set 8 | roma
# Processing Record 1 of Set 9 | arzgir
# Processing Record 2 of Set 9 | sunrise manor
# Processing Record 3 of Set 9 | champerico
# Processing Record 4 of Set 9 | hun
# Processing Record 5 of Set 9 | luba
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | quatre cocos
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | rosario
# Processing Record 10 of Set 9 | batticaloa
# Processing Record 11 of Set 9 | alekseyevka
# Processing Record 12 of Set 9 | tazmalt
# Processing Record 13 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | hovd
# Processing Record 16 of Set 9 | barahona
# Processing Record 17 of Set 9 | chumikan
# Processing Record 18 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 19 of Set 9 | kolyvan
# Processing Record 20 of Set 9 | bellavista
# Processing Record 21 of Set 9 | ekibastuz
# Processing Record 22 of Set 9 | katsuura
# Processing Record 23 of Set 9 | henties bay
# Processing Record 24 of Set 9 | aborlan
# Processing Record 25 of Set 9 | erdaojiang
# Processing Record 26 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 9 | beitbridge
# Processing Record 28 of Set 9 | clovis
# Processing Record 29 of Set 9 | corrente
# Processing Record 30 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 32 of Set 9 | kotaparh
# Processing Record 33 of Set 9 | lompoc
# Processing Record 34 of Set 9 | camacha
# Processing Record 35 of Set 9 | kenai
# Processing Record 36 of Set 9 | vuktyl
# Processing Record 37 of Set 9 | himora
# City not found. Skipping...
# Processing Record 38 of Set 9 | clarksburg
# Processing Record 39 of Set 9 | mabaruma
# Processing Record 40 of Set 9 | akonolinga
# Processing Record 41 of Set 9 | ahar
# Processing Record 42 of Set 9 | kyra
# Processing Record 43 of Set 9 | shellbrook
# Processing Record 44 of Set 9 | muros
# Processing Record 45 of Set 9 | parabel
# Processing Record 46 of Set 9 | tabuk
# Processing Record 47 of Set 9 | tabas
# Processing Record 48 of Set 9 | shasta lake
# Processing Record 49 of Set 9 | mangulile
# Processing Record 50 of Set 9 | maridi
# Processing Record 1 of Set 10 | sioux lookout
# Processing Record 2 of Set 10 | kavaratti
# Processing Record 3 of Set 10 | wagar
# Processing Record 4 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 5 of Set 10 | yeniseysk
# Processing Record 6 of Set 10 | boone
# Processing Record 7 of Set 10 | nefteyugansk
# Processing Record 8 of Set 10 | goma
# Processing Record 9 of Set 10 | lufilufi
# Processing Record 10 of Set 10 | muli
# Processing Record 11 of Set 10 | xichang
# Processing Record 12 of Set 10 | naron
# Processing Record 13 of Set 10 | tongchuan
# Processing Record 14 of Set 10 | tommot
# Processing Record 15 of Set 10 | boddam
# Processing Record 16 of Set 10 | kyabram
# Processing Record 17 of Set 10 | uruzgan
# Processing Record 18 of Set 10 | kattivakkam
# Processing Record 19 of Set 10 | karpathos
# Processing Record 20 of Set 10 | nosy varika
# Processing Record 21 of Set 10 | suratgarh
# Processing Record 22 of Set 10 | comodoro rivadavia
# Processing Record 23 of Set 10 | plettenberg bay
# Processing Record 24 of Set 10 | bartica
# Processing Record 25 of Set 10 | klamath falls
# Processing Record 26 of Set 10 | san carlos de bariloche
# Processing Record 27 of Set 10 | constantine
# Processing Record 28 of Set 10 | tokoname
# Processing Record 29 of Set 10 | capaci
# Processing Record 30 of Set 10 | aklavik
# Processing Record 31 of Set 10 | causwagan
# Processing Record 32 of Set 10 | umrala
# Processing Record 33 of Set 10 | keffi
# Processing Record 34 of Set 10 | aguililla
# Processing Record 35 of Set 10 | saint-omer
# Processing Record 36 of Set 10 | maniitsoq
# Processing Record 37 of Set 10 | constitucion
# Processing Record 38 of Set 10 | voh
# Processing Record 39 of Set 10 | port augusta
# Processing Record 40 of Set 10 | nanortalik
# Processing Record 41 of Set 10 | chulman
# Processing Record 42 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 10 | yar-sale
# Processing Record 44 of Set 10 | la sarre
# Processing Record 45 of Set 10 | teya
# Processing Record 46 of Set 10 | kangaatsiaq
# Processing Record 47 of Set 10 | nakusp
# Processing Record 48 of Set 10 | hualmay
# Processing Record 49 of Set 10 | qingdao
# Processing Record 50 of Set 10 | sexsmith
# Processing Record 1 of Set 11 | hue
# Processing Record 2 of Set 11 | te anau
# Processing Record 3 of Set 11 | doha
# Processing Record 4 of Set 11 | port-de-bouc
# Processing Record 5 of Set 11 | cananeia
# Processing Record 6 of Set 11 | ionia
# Processing Record 7 of Set 11 | muzhi
# Processing Record 8 of Set 11 | paranaiba
# Processing Record 9 of Set 11 | saint-leu
# Processing Record 10 of Set 11 | sovetsk
# Processing Record 11 of Set 11 | eureka
# Processing Record 12 of Set 11 | envira
# Processing Record 13 of Set 11 | ishigaki
# Processing Record 14 of Set 11 | salinopolis
# Processing Record 15 of Set 11 | karratha
# Processing Record 16 of Set 11 | ballina
# Processing Record 17 of Set 11 | humboldt
# Processing Record 18 of Set 11 | cabo san lucas
# Processing Record 19 of Set 11 | qaqortoq
# Processing Record 20 of Set 11 | khor
# Processing Record 21 of Set 11 | gat
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | ostrovnoy
# Processing Record 24 of Set 11 | blatna
# Processing Record 25 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 11 | ugoofaaru
# Processing Record 27 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 11 | saint anthony
# Processing Record 30 of Set 11 | wajir
# Processing Record 31 of Set 11 | jiuquan
# Processing Record 32 of Set 11 | avera
# Processing Record 33 of Set 11 | aykhal
# Processing Record 34 of Set 11 | slantsy
# Processing Record 35 of Set 11 | neuquen
# Processing Record 36 of Set 11 | idrinskoye
# Processing Record 37 of Set 11 | dubuque
# Processing Record 38 of Set 11 | yumen
# Processing Record 39 of Set 11 | fortuna
# Processing Record 40 of Set 11 | corralillo
# Processing Record 41 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 11 | hamilton
# Processing Record 43 of Set 11 | nombre de dios
# Processing Record 44 of Set 11 | bela
# Processing Record 45 of Set 11 | tiznit
# Processing Record 46 of Set 11 | bonthe
# Processing Record 47 of Set 11 | dargaville
# Processing Record 48 of Set 11 | tual
# Processing Record 49 of Set 11 | biak
# Processing Record 50 of Set 11 | oranjemund
# Processing Record 1 of Set 12 | aksu
# Processing Record 2 of Set 12 | jumla
# Processing Record 3 of Set 12 | domoni
# Processing Record 4 of Set 12 | braganca
# Processing Record 5 of Set 12 | iquitos
# Processing Record 6 of Set 12 | atherton
# Processing Record 7 of Set 12 | newcastle
# Processing Record 8 of Set 12 | sibolga
# Processing Record 9 of Set 12 | hermagor
# Processing Record 10 of Set 12 | puerto escondido
# Processing Record 11 of Set 12 | mahibadhoo
# Processing Record 12 of Set 12 | qandala
# Processing Record 13 of Set 12 | cordoba
# Processing Record 14 of Set 12 | lasa
# Processing Record 15 of Set 12 | totma
# Processing Record 16 of Set 12 | george
# Processing Record 17 of Set 12 | lakes entrance
# Processing Record 18 of Set 12 | kingaroy
# Processing Record 19 of Set 12 | bethanien
# Processing Record 20 of Set 12 | lake charles
# Processing Record 21 of Set 12 | xining
# Processing Record 22 of Set 12 | chachapoyas
# Processing Record 23 of Set 12 | tecoanapa
# Processing Record 24 of Set 12 | los llanos de aridane
# Processing Record 25 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 12 | hede
# Processing Record 27 of Set 12 | northam
# Processing Record 28 of Set 12 | basco
# Processing Record 29 of Set 12 | fairbanks
# Processing Record 30 of Set 12 | ukiah
# Processing Record 31 of Set 12 | mpika
# Processing Record 32 of Set 12 | afyonkarahisar
# Processing Record 33 of Set 12 | nakonde
# Processing Record 34 of Set 12 | williams lake
# Processing Record 35 of Set 12 | phangnga
# Processing Record 36 of Set 12 | san cristobal
# Processing Record 37 of Set 12 | tuatapere
# Processing Record 38 of Set 12 | temyasovo
# Processing Record 39 of Set 12 | riachao do jacuipe
# Processing Record 40 of Set 12 | mosetse
# Processing Record 41 of Set 12 | hargeysa
# Processing Record 42 of Set 12 | stournaraiika
# City not found. Skipping...
# Processing Record 43 of Set 12 | simbahan
# Processing Record 44 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 45 of Set 12 | matagami
# Processing Record 46 of Set 12 | zhigansk
# Processing Record 47 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | yining
# Processing Record 49 of Set 12 | bereda
# Processing Record 50 of Set 12 | wahiawa
# Processing Record 1 of Set 13 | tarauaca
# Processing Record 2 of Set 13 | valparaiso
# Processing Record 3 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 13 | cullman
# Processing Record 5 of Set 13 | north bend
# Processing Record 6 of Set 13 | wad rawah
# Processing Record 7 of Set 13 | ascension
# Processing Record 8 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 13 | nome
# Processing Record 10 of Set 13 | houma
# Processing Record 11 of Set 13 | paracuru
# Processing Record 12 of Set 13 | udachnyy
# Processing Record 13 of Set 13 | guerrero negro
# Processing Record 14 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 13 | mangrol
# Processing Record 16 of Set 13 | abrau-dyurso
# Processing Record 17 of Set 13 | lubumbashi
# Processing Record 18 of Set 13 | shu
# Processing Record 19 of Set 13 | ayr
# Processing Record 20 of Set 13 | kokopo
# Processing Record 21 of Set 13 | terney
# Processing Record 22 of Set 13 | half moon bay
# Processing Record 23 of Set 13 | tam ky
# Processing Record 24 of Set 13 | ranong
# Processing Record 25 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 26 of Set 13 | kon tum
# Processing Record 27 of Set 13 | bazarnyye mataki
# Processing Record 28 of Set 13 | oistins
# Processing Record 29 of Set 13 | odweyne
# Processing Record 30 of Set 13 | tinjah
# City not found. Skipping...
# Processing Record 31 of Set 13 | sayat
# Processing Record 32 of Set 13 | ossora
# Processing Record 33 of Set 13 | kibala
# Processing Record 34 of Set 13 | ust-kuyga
# Processing Record 35 of Set 13 | jizan
# Processing Record 36 of Set 13 | anzio
# Processing Record 37 of Set 13 | baturaja
# Processing Record 38 of Set 13 | nizhniy odes
# Processing Record 39 of Set 13 | meulaboh
# Processing Record 40 of Set 13 | tukrah
# Processing Record 41 of Set 13 | anloga
# Processing Record 42 of Set 13 | raton
# Processing Record 43 of Set 13 | antofagasta
# Processing Record 44 of Set 13 | kwekwe
# Processing Record 45 of Set 13 | kaeo
# Processing Record 46 of Set 13 | maningrida
# Processing Record 47 of Set 13 | aleksandrov gay
# Processing Record 48 of Set 13 | orissaare
# Processing Record 49 of Set 13 | celestun
# Processing Record 50 of Set 13 | odesskoye
# Processing Record 1 of Set 14 | jieshi
# Processing Record 2 of Set 14 | shunyi
# Processing Record 3 of Set 14 | ventspils
# Processing Record 4 of Set 14 | san pedro del pinatar
# Processing Record 5 of Set 14 | labuan
# Processing Record 6 of Set 14 | shirokiy
# Processing Record 7 of Set 14 | arawa
# Processing Record 8 of Set 14 | tuy hoa
# Processing Record 9 of Set 14 | kichera
# Processing Record 10 of Set 14 | vaitape
# Processing Record 11 of Set 14 | madeji
# Processing Record 12 of Set 14 | le mars
# Processing Record 13 of Set 14 | cervo
# Processing Record 14 of Set 14 | finschhafen
# Processing Record 15 of Set 14 | jamsa
# Processing Record 16 of Set 14 | kapuskasing
# Processing Record 17 of Set 14 | alofi
# Processing Record 18 of Set 14 | aasiaat
# Processing Record 19 of Set 14 | taksimo
# Processing Record 20 of Set 14 | laguna
# Processing Record 21 of Set 14 | lagoa
# Processing Record 22 of Set 14 | caravelas
# Processing Record 23 of Set 14 | kalulushi
# Processing Record 24 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 14 | bhabua
# Processing Record 26 of Set 14 | karoi
# Processing Record 27 of Set 14 | lima
# Processing Record 28 of Set 14 | wanaka
# Processing Record 29 of Set 14 | moron
# Processing Record 30 of Set 14 | sept-iles
# Processing Record 31 of Set 14 | tanete
# Processing Record 32 of Set 14 | kalayaan
# Processing Record 33 of Set 14 | aracuai
# Processing Record 34 of Set 14 | pingshan
# Processing Record 35 of Set 14 | gao
# Processing Record 36 of Set 14 | tucurui
# Processing Record 37 of Set 14 | szubin
# Processing Record 38 of Set 14 | revelstoke
# Processing Record 39 of Set 14 | ngunguru
# Processing Record 40 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 14 | picton
# Processing Record 42 of Set 14 | sompeta
# Processing Record 43 of Set 14 | ikungi
# Processing Record 44 of Set 14 | muswellbrook
# Processing Record 45 of Set 14 | brufut
# Processing Record 46 of Set 14 | maarianhamina
# Processing Record 47 of Set 14 | blairmore
# Processing Record 48 of Set 14 | sur
# Processing Record 49 of Set 14 | newtownards
# Processing Record 50 of Set 14 | makushino
# Processing Record 1 of Set 15 | mana
# Processing Record 2 of Set 15 | vostok
# Processing Record 3 of Set 15 | gold coast
# Processing Record 4 of Set 15 | lexington
# Processing Record 5 of Set 15 | tilichiki
# Processing Record 6 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 15 | port macquarie
# Processing Record 8 of Set 15 | ornskoldsvik
# Processing Record 9 of Set 15 | mandalgovi
# Processing Record 10 of Set 15 | bud
# Processing Record 11 of Set 15 | flinders
# Processing Record 12 of Set 15 | hirara
# Processing Record 13 of Set 15 | cascais
# Processing Record 14 of Set 15 | cam ranh
# Processing Record 15 of Set 15 | fomboni
# Processing Record 16 of Set 15 | igrim
# Processing Record 17 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 15 | egvekinot
# Processing Record 19 of Set 15 | svetlogorsk
# Processing Record 20 of Set 15 | blagoyevo
# Processing Record 21 of Set 15 | mayumba
# Processing Record 22 of Set 15 | zatoka
# Processing Record 23 of Set 15 | praia da vitoria
# Processing Record 24 of Set 15 | guano
# Processing Record 25 of Set 15 | farmington
# Processing Record 26 of Set 15 | omboue
# Processing Record 27 of Set 15 | juye
# Processing Record 28 of Set 15 | marienburg
# Processing Record 29 of Set 15 | balakhta
# Processing Record 30 of Set 15 | ramasukha
# City not found. Skipping...
# Processing Record 31 of Set 15 | hervey bay
# Processing Record 32 of Set 15 | paka
# Processing Record 33 of Set 15 | havre-saint-pierre
# Processing Record 34 of Set 15 | xiashi
# Processing Record 35 of Set 15 | ocos
# Processing Record 36 of Set 15 | kandrian
# Processing Record 37 of Set 15 | jiazi
# Processing Record 38 of Set 15 | itoman
# Processing Record 39 of Set 15 | chapais
# Processing Record 40 of Set 15 | hobyo
# Processing Record 41 of Set 15 | saint-georges
# Processing Record 42 of Set 15 | kanniyakumari
# Processing Record 43 of Set 15 | chancay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Helena  46.5927 -112.0361     16.79        80         100
# 1         Albany  42.6001  -73.9662     55.29        40           2
# 2         Rawson -43.3002  -65.1023     66.34        34           0
# 3       Thompson  55.7435  -97.8558      8.76        56          75
# 4       Cherskiy  68.7500  161.3000      7.11        99          89
# 5  Mar Del Plata -38.0023  -57.5575     58.87        79           0
# 6          Tiksi  71.6872  128.8694     -0.89       100         100
# 7      Mahebourg -20.4081   57.7000     80.26        73          40
# 8          Airai  -8.9266  125.4092     62.60        94         100
# 9       Portland  45.5234 -122.6762     36.68        95          75
#
#    Wind Speed Current Description
# 0        5.75     overcast clouds
# 1        4.00           clear sky
# 2       19.98           clear sky
# 3       11.50       broken clouds
# 4        5.66     overcast clouds
# 5        7.00           clear sky
# 6        5.91     overcast clouds
# 7       12.66    scattered clouds
# 8        2.57     overcast clouds
# 9        3.44                mist

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
